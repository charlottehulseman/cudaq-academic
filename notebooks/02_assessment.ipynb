# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Quantum Quest Assessment\n",
    "## Find Your Personalized Learning Path"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Interactive Assessment\n",
    "import json\n",
    "\n",
    "print('🎮 QUANTUM QUEST ASSESSMENT')\n",
    "print('=' * 40)\n",
    "\n",
    "score = 0\n",
    "prerequisites = []\n",
    "\n",
    "# Question 1\n",
    "print('\\n1. Your background?')\n",
    "print('a) CS  b) Physics  c) Chemistry  d) Math  e) Other')\n",
    "bg = input('Answer: ').lower()\n",
    "\n",
    "if bg == 'a':\n",
    "    path = 'code_first'\n",
    "elif bg == 'b':\n",
    "    path = 'theory_first'\n",
    "else:\n",
    "    path = 'visual_first'\n",
    "    prerequisites.append('python_basics')\n",
    "\n",
    "# Question 2\n",
    "ans = input('\\n2. What is [1,2,3][-1]? ')\n",
    "if ans == '3':\n",
    "    score += 1\n",
    "else:\n",
    "    prerequisites.append('python_review')\n",
    "\n",
    "# Results\n",
    "print(f'\\n📊 Your Path: {path}')\n",
    "print(f'📚 Prerequisites: {\", \".join(prerequisites) if prerequisites else \"None\"}')\n",
    "print(f'⏱️ Time to start: {len(prerequisites) * 2} hours')"
   ]
  }
 ]
}
